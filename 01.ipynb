# %%
from PIL import Image

# %%
dir = 'C:/Users/Admin/Downloads/arnh/hi.jpg'

# %%
print (dir)
# Out:
# C:/Users/Admin/Downloads/arnh/hi.jpg

# %%
img01 = Image.open(dir)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x800>
