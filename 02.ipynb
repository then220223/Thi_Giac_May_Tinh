# %%
from imgtools import *

# %%
my_dir = 'C:/Users/Admin/Desktop/thi_giac_may_tinh'

# %%
imgs = get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (300, 168)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>
# (600, 800)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x800>
# (183, 275)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>
# (241, 209)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=241x209>
